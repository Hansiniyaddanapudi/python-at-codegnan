# %%
Name = "Hansini"
age = 20
city = "Nandyal"
career_goal = "Software developer"
print("Name:",Name)
print("age:",age)
print("city:",city)
print("career_goal:",career_goal)
# Out:
# Name: Hansini
# age: 20
# city: Nandyal
# career_goal: Software developer

# %%
Clg_name = "st joseph's clg"
Year_of_study = 2023-2026
Branch = "Bca"
print("Clg_name:",Clg_name)
print("Year_of_study:",Year_of_study)
print("Branch:",Branch)
# Out:
# Clg_name: st joseph's clg
# Year_of_study: -3
# Branch: Bca

# %%
print("9:00 am is python")
print("11:00 am is Aptitude")
print("2:00 pm is soft skills")
print("4:00 pm is practice session")
# Out:
# 9:00 am is python
# 11:00 am is Aptitude
# 2:00 pm is soft skills
# 4:00 pm is practice session

# %%
Python ="9:00 am-python"
aptitude ="11:00 am-aptitude"
softSkills ="2:00 pm-softSkills"
practicesession ="4:00 pm-practicesession"
print(Python)
print(aptitude)
print(softSkills)
print(practicesession)
# Out:
# 9:00 am-python
# 11:00 am-aptitude
# 2:00 pm-softSkills
# 4:00 pm-practicesession

# %%
variable_name = "Honey"
print(variable_name)
# Out:
# Honey

# %%
Full_name = "Hansini Yaddanapudi"
Head_line = "Python Full Stack Trainee Intern at Codegnan | Python | Django | SQL | Web Development"
E_mail = "hansiniyaddanapudi@gmail.com"
About = "Aspiring Software Developer currently working as a Python Full Stack Intern at Codegnan. Passionate about web development, problem-solving, and continuously learning new technologies. Skilled in Python, HTML, CSS, JavaScript, and SQL, with experience in developing responsive and user-friendly web applications. Eager to apply technical expertise, expand professional skills, and contribute to innovative software solutions in a collaborative environment"
Experience = "Full stack trainee at codegnan"
company_name = "Codegnan"
Role = "Trainee"
Skills = "Python (Programming Language),MySQL,HTML5,Django,JavaScript"
Year = "June 2026-present"
print(Full_name)
print(Head_line)
print(E_mail)
print(About)
print(Experience)
print(company_name)
print(Role)
print(Skills)
print(Year)
# Out:
# Hansini Yaddanapudi
# Python Full Stack Trainee Intern at Codegnan | Python | Django | SQL | Web Development
# hansiniyaddanapudi@gmail.com
# Aspiring Software Developer currently working as a Python Full Stack Intern at Codegnan. Passionate about web development, problem-solving, and continuously learning new technologies. Skilled in Python, HTML, CSS, JavaScript, and SQL, with experience in developing responsive and user-friendly web applications. Eager to apply technical expertise, expand professional skills, and contribute to innovative software solutions in a collaborative environment
# Full stack trainee at codegnan
# Codegnan
# Trainee
# Python (Programming Language),MySQL,HTML5,Django,JavaScript
# June 2026-present

# %%
marks = int(input("Enter student marks"))
print("student marks=",marks)
# Out:
# Enter student marks 67
# student marks= 67

# %%
sub1 = int(input("enter subject 1 marks"))
sub2 = int(input("enter subject 2 marks"))
sub3 = int(input("enter subject 3 marks"))
sub4 = int(input("enter subject 4 marks"))
sub5 = int(input("enter subject 5 marks"))
total = sub1+sub2+sub3+sub4+sub5
Average = total/5
print("sub1 marks=",marks)
print("sub2 marks=",marks)
print("sub3 marks=",marks)
print("sub4 marks=",marks)
print("sub5 marks=",marks)
print("total marks=",total)
print("Average marks=",Average)
# Out:
# enter subject 1 marks 56
# enter subject 2 marks 45
# enter subject 3 marks 67
# enter subject 4 marks 78
# enter subject 5 marks 90
# sub1 marks= 67
# sub2 marks= 67
# sub3 marks= 67
# sub4 marks= 67
# sub5 marks= 67
# total marks= 336
# Average marks= 67.2

# %%
birth_year = int(input("enter the birth year"))
current_year = 2026
age = current_year-birth_year
print("your age is",age)
# Out:
# enter the birth year 2006
# yur age is 20

# %%
length = int(input("enter the length of the rectangle"))
width = int(input("enter the width of the rectangle"))
area = length * width
print("area of rectangle=",area)
# Out:
# enter the length of the rectangle 450
# enter the width of the rectangle 339
# area of rectangle= 152550

# %%
radius = float(input("Enter the radius:"))
area = 3.14*radius*radius
print("area of circle=",area)
# Out:
# Enter the radius: 56
# area of circle= 9847.04

# %%
r = float(input())
pi = 3.141592653
print(pi * r ** 2)
# Out:
#  123
# 47529.155247237

# %%
units = int(input())
age = input()
if(units > 0 and units <= 100):
    t_bill = units * 1.5
    print(t_bill)
elif (units >100 and units <= 200):
    t_bill = units * 2.5
    print(t_bill)
elif(units >200 and units <= 500):
        t_bill = units * 4.0
        print(t_bill)
else:
    t_bill = units*6
    print(t_bill)
if(age == "senior"):
    bill = t_bill-(t_bill*(10/100))
    print(bill)
else:
    print(t_bill)
# Out:
#  1250
#  1250

# %%
# palindrome or not
s = input()
s2 = input()
if s1 == s1[::-1]:
    if s2 == s2[::-1]:
        print("True")
    else:
        print("False")
# Out:
#  madam
#  mom
# True

# %%
# sum of digits in a string
s = "abc123def456"
total = 0 
for i in s:
    if i.isdigit():
        total = total+int(i)
print(total)
# Out:
# 21

# %%
# number palindrome
num = int(input())
if s == s[::-1]:
    print("True")
else:
    print("False")
# Out:
#  12121
# True

# %%
# Loan Approval System
credit_score = int(input("Enter Credit Score: "))
income = int(input("Enter Monthly Income: "))
liabilities = int(input("Enter Existing Liabilities: "))
if credit_score >= 750:
    credit_status = "Eligible"
elif 650 <= credit_score <= 749:
    credit_status = "Conditional"
else:
    credit_status = "Rejected"
income_status = income >= 50000
liability_status = liabilities <= 20000
if credit_status == "Eligible" and income_status and liability_status:
    print("Loan Approved")
elif credit_status == "Conditional" and income_status and liability_status:
    print("Loan Approved with Conditions")
else:
    print("Loan Rejected")
# Out:
# Enter Credit Score:  150000
# Enter Monthly Income:  35000
# Enter Existing Liabilities:  2000
# Loan Rejected

# %%
print(int(input()*55)
# Out:
#   Cell In[17], line 3
#
#     ^
# _IncompleteInputError: incomplete input
