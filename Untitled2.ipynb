# %%
Name = "Hansini"
age = 20
city = "Nandyal"
career_goal = "Software developer"
print("Name:",Name)
print("age:",age)
print("city:",city)
print("career_goal:",career_goal)
# Out:
# Name: Hansini
# age: 20
# city: Nandyal
# career_goal: Software developer

# %%
Clg_name = "st joseph's clg"
Year_of_study = 2023-2026
Branch = "Bca"
print("Clg_name:",Clg_name)
print("Year_of_study:",Year_of_study)
print("Branch:",Branch)
# Out:
# Clg_name: st joseph's clg
# Year_of_study: -3
# Branch: Bca

# %%
print("9:00 am is python")
print("11:00 am is Aptitude")
print("2:00 pm is soft skills")
print("4:00 pm is practice session")
# Out:
# 9:00 am is python
# 11:00 am is Aptitude
# 2:00 pm is soft skills
# 4:00 pm is practice session
