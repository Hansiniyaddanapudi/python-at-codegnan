# %% [markdown]
# ### Input Formating

# %%
# reading integer from user
num = int(input("Enter a number:"))
print(type(num))
print(num)
# Out:
# Enter a number: 18
# <class 'int'>
# 18

# %%
# Reading float value from user
val = float(input())
print(type(val))
print(val)
# Out:
#  29.428
# <class 'float'>
# 29.428

# %%
# complex reading from user
val = complex(int(input()),int(input()))
print(type(val))
print(val)
# Out:
#  18
#  29
# <class 'complex'>
# (18+29j)

# %%
# boolean reading
val = bool(input()),
print(type(val))
print(val)
# Out:
#  10
# <class 'tuple'>
# (True,)

# %%
# boolean reading as integer
val = bool(int(input()))
print(type(val))
print(val)
# Out:
#  0
# <class 'bool'>
# False

# %%
# reading string value from user
val = str(input())
print(type(val))
print(val)
# Out:
#  18
# <class 'str'>
# 18

# %%
# reading list of integers from user
lst = (input().(split))
print(lst)
# Out:
#  9,2,8
# 9,2,8

# %%
# reading list of integers from user
lst = lst(map(int,input().split()))
print(lst)
# Out:
#  18 27 89
# [18, 27, 89]

# %%
# reading list of string from user
lst = list(map(str, input().split(',')))
print(lst)
# Out:
#  2,6,9
# ['2', '6', '9']

# %%
# approach 2

# %%
# reading tuple of string from user
lst = tuple(map(str, input().split()))
print(lst)
# Out:
#  27 18 45
# ('27', '18', '45')

# %%
# eval(): This function evaluates the string type expression
val = eval(input())
print(type(val))
print(val)
# Out:
#  18
# <class 'int'>
# 18

# %%
val = eval(input())
print(type(val))
print(val)
# Out:
#  84.3
# <class 'float'>
# 84.3

# %%
val = eval(input())
print(type(val))
print(val)
# Out:
#  20 + 6J
# <class 'complex'>
# (20+6j)

# %%
val = eval(input())
print(type(val))
print(val)
# Out:
#  ['Honey',57,'python']
# <class 'list'>
# ['Honey', 57, 'python']

# %%
print("3+5")
print(eval("3+5"))
# Out:
# 3+5
# 8

# %% [markdown]
# ### Output formating

# %%
name ="Honey"
age = 20
# my name is Honey and i am 20 yrs old
print("My name is" + name +"and i am"+ str(age) + "years old")
# Out:
# My name isHoneyand i am20years old

# %%
# 1. String formatting usind comma
name ="Honey"
age = 20
# my name is Honey and i am 20 yrs old
print("My name is", name,"and i am", age,"years old")
# Out:
# My name is Honey and i am 20 years old

# %%
# 2.Access Specifiers
# string - %s
# integer - %d
# float - %f
name ="Honey"
age = 20
# my name is Honey and i am 20 yrs old
print("My name is %s and i am %d years old"%(name,age))
# Out:
# My name is Honey and i am 20 years old

# %%
name ="Honey"
age = 20
# my name is Honey and i am 20 yrs old
print(" i am %d years old and My name is %s "%(age,name))
# Out:
#  i am 20 years old and My name is Honey

# %%
# 3.dot format
name ="Honey"
age = 20
# my name is Honey and i am 20 yrs old
print("My name is {} and i am {} years old".format(name,age))
print("My name is {} and i am {} years old".format(age,name))
# Out:
# My name is Honey and i am 20 years old
# My name is 20 and i am Honey years old

# %%
# 4 f-format
name ="Honey"
age = 20
# my name is Honey and i am 20 yrs old
print(f"My name is {name} and i am {age} years old")
print(f"My name is {age} and i am {name} years old")
# Out:
# My name is Honey and i am 20 years old
# My name is 20 and i am Honey years old
